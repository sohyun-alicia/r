# %%
# swiss 활용해서 데이터 정보확인

dim(swiss)
# Out:
# [1] 47  6

# %%
head(swiss)
# Out:
#              Fertility Agriculture Examination Education Catholic
# Courtelary   80.2      17.0        15          12         9.96
# Delemont     83.1      45.1         6           9        84.84
# Franches-Mnt 92.5      39.7         5           5        93.40
# Moutier      85.8      36.5        12           7        33.77
# Neuveville   76.9      43.5        17          15         5.16
# Porrentruy   76.1      35.3         9           7        90.57
#              Infant.Mortality
# Courtelary   22.2
# Delemont     22.2
# Franches-Mnt 20.2
# Moutier      20.3
# Neuveville   20.6
# Porrentruy   26.6

# %%
tail(swiss)
# Out:
#              Fertility Agriculture Examination Education Catholic
# Neuchatel    64.4      17.6        35          32        16.92
# Val de Ruz   77.6      37.6        15           7         4.97
# ValdeTravers 67.6      18.7        25           7         8.65
# V. De Geneve 35.0       1.2        37          53        42.34
# Rive Droite  44.7      46.6        16          29        50.43
# Rive Gauche  42.8      27.7        22          29        58.33
#              Infant.Mortality
# Neuchatel    23.0
# Val de Ruz   20.0
# ValdeTravers 19.5
# V. De Geneve 18.0
# Rive Droite  18.2
# Rive Gauche  19.3

# %%
str(swiss)
# Out:
# 'data.frame':	47 obs. of  6 variables:
#  $ Fertility       : num  80.2 83.1 92.5 85.8 76.9 76.1 83.8 92.4 82.4 82.9 ...
#  $ Agriculture     : num  17 45.1 39.7 36.5 43.5 35.3 70.2 67.8 53.3 45.2 ...
#  $ Examination     : int  15 6 5 12 17 9 16 14 12 16 ...
#  $ Education       : int  12 9 5 7 15 7 7 8 7 13 ...
#  $ Catholic        : num  9.96 84.84 93.4 33.77 5.16 ...
#  $ Infant.Mortality: num  22.2 22.2 20.2 20.3 20.6 26.6 23.6 24.9 21 24.4 ...

# %%
#  데이터 그리기

plot(swiss$Fertility)
# Out:
# plot without title

# %%
plot(swiss$Fertility, swiss$Catholic)
# Out:
# plot without title

# %%
plot(swiss$Fertility, swiss$Catholic, main = "swiss data", xlab = "Fertility Rate", ylab = "Catholic Rate")
# Out:
# Plot with title "swiss data"

# %%
pairs(~ Fertility + Catholic + Education + Infant.Mortality, data = swiss)
# Out:
# plot without title

# %%
hist(swiss$Catholic)
# Out:
# Plot with title "Histogram of swiss$Catholic"

# %%
hist(swiss$Catholic, freq=FALSE)
# Out:
# Plot with title "Histogram of swiss$Catholic"
